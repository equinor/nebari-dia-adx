# %%
#| hide
from nebari_dia_adx.core import *

# %% [markdown]
# # nebari-dia-adx
#
# > Repo for modules to connect to adx

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nebari_dia_adx in Development mode

# %% [markdown]
# ```sh
# # make sure nebari_dia_adx package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nebari_dia_adx
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/equinor/nebari-dia-adx.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c equinor nebari_dia_adx
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nebari_dia_adx
# ```
#
#
# [repo]: https://github.com/equinor/nebari-dia-adx
# [docs]: https://equinor.github.io/nebari-dia-adx/
# [pypi]: https://pypi.org/project/nebari-dia-adx/
# [conda]: https://anaconda.org/equinor/nebari-dia-adx

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/equinor/nebari-dia-adx
# [docs]: https://equinor.github.io/nebari-dia-adx/
# [pypi]: https://pypi.org/project/nebari-dia-adx/
# [conda]: https://anaconda.org/equinor/nebari-dia-adx

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
